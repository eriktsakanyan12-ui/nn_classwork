# %%
import torch
from models import SimpleNN

epochs = 5
losses = []
model = SimpleNN()
for epoch in range(epochs):
    
    checkpoint = torch.load(f'.\model_checkpoints\mnist_simplenn_weights_epoch{epoch}.pth')
    model.load_state_dict(checkpoint)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\User\AppData\Local\Temp\ipykernel_11124\1050920599.py:9: SyntaxWarning: invalid escape sequence '\m'
#   checkpoint = torch.load(f'.\model_checkpoints\mnist_simplenn_weights_epoch{epoch}.pth')

# %%
pwd
# Out:
# 'c:\\Users\\User\\nn_classwork'
